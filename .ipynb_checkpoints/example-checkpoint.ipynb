# %%
# automatically reload each function when called for development
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Initializing the model and running the MCMC

# %%
# Import the PNGmodel class
from codes.PNGmodel import PNGmodel

# %% [markdown]
# ### Initialize the model and load all data

# %%
mod = PNGmodel(fid_corr = './inputs/abacus_averaged_fiducial_wts_fixed.fits', 
               cov_pkg = './inputs/EZ_mock_covariance_matrix.npy', 
               # exclude=['xi2','xi4'],
               # s_max=380, 
               s_cutwindow = [90, 130])

mod.load_PNG_model(png_quadfits_files = ['./inputs/quadfits_LRG_FastPM_Y3_fnl_xi0.csv',
                                         './inputs/quadfits_LRG_FastPM_Y3_fnl_xi2.csv',
                                         './inputs/quadfits_LRG_FastPM_Y3_fnl_xi4.csv'])

mod.load_covariance()

mod.load_photo_vary_fits(pkg_set1 = ['./inputs/quadfits_LRG_abacus_Y1_Ksys_SGC_xi0.csv',
                                     './inputs/quadfits_LRG_abacus_Y1_Ksys_SGC_xi2.csv',
                                     './inputs/quadfits_LRG_abacus_Y1_Ksys_SGC_xi4.csv'],
                         pkg_set2 = ['./inputs/quadfits_LRG_abacus_Y1_Ksys_DEC_xi0.csv',
                                     './inputs/quadfits_LRG_abacus_Y1_Ksys_DEC_xi2.csv',
                                     './inputs/quadfits_LRG_abacus_Y1_Ksys_DEC_xi4.csv'],
                         pkg_set3 = ['./inputs/quadfits_LRG_abacus_Y1_Ksys_MZLS_xi0.csv',
                                     './inputs/quadfits_LRG_abacus_Y1_Ksys_MZLS_xi2.csv',
                                     './inputs/quadfits_LRG_abacus_Y1_Ksys_MZLS_xi4.csv'])
# Out:
# Initializing...
# Observable will have 99 pts
# Loading PNG model...
# Loading covariance matrix...
# Loading systematic weight variation...

# %%
type(mod)
# Out:
# codes.PNGmodel.PNGmodel

# %% [markdown]
# ### Run the mcmc sampling
#
# NOTICE: all of the chain output text files are saved on github so if you don't want to rerun these steps, you can skip to plotting below.

# %%
mod.test_model_base_pars(min_type = 'data',
                         poi_hard_lims = ((-250,250),(0.5,4)), 
                         gauss_priors = ((1.94,0.04),(1.94,0.04),(1,0.1),(1,0.1)),
                         Psys1_gauss_prior = (0,10),
                         Psys2_gauss_prior = (0,10),
                         Psys3_gauss_prior = (0,10),
                         z_eff = 0.780, # v1.5 0.780, nbody png 0.787
                         Om_m0_g = 0.315,
                         z_fid = 0.776,
                         zhalo = 0.787, # box 0.819, y3 0.787
                         Om_m0_h = 0.3089, #
                         nwalkers = 75, #50
                         nsteps = 20000, # Should default to 20000, set to 2000 for code testing
                         plt_color = 'green',
                         fname = None, 
                         # poi_toy = (0,1.8), nuiss_toy = (1.8, 1.8, 1, 1), Psys1_toy = 0, Psys2_toy = 0, Psys3_toy = 0,
                         data_obs = f'./inputs/Y1_LRG_correlations_v1.5_.fits',
                         plt_out = True)
# Out:
# Exploring parameter space...
# 100%|██████████| 20000/20000 [07:08<00:00, 46.68it/s]

# %% [markdown]
# ### Save the output

# %%
mod.wrap_chain_base_pars(burn_in_steps = 500, thinner = 1,
                         fname_chain = f'./outputs/testchain.txt')

# %% [markdown]
# ### Run toy data so we can plot multiple chains later

# %%
fnls_toy = [-20, -10, 0, 10, 20]
b1s_toy = [1.6, 1.7, 1.8, 1.9, 2.0]

for fnl, b1 in zip(fnls_toy, b1s_toy):
    toy = PNGmodel(fid_corr = './inputs/abacus_averaged_fiducial_wts_fixed.fits', 
                cov_pkg = './inputs/EZ_mock_covariance_matrix.npy', 
                exclude=['xi2','xi4'],
                s_max=380, s_cutwindow = [90, 130])

    toy.load_PNG_model(png_quadfits_files = ['./inputs/quadfits_LRG_FastPM_Y3_fnl_xi0.csv',
                                            './inputs/quadfits_LRG_FastPM_Y3_fnl_xi2.csv',
                                            './inputs/quadfits_LRG_FastPM_Y3_fnl_xi4.csv'])

    toy.load_covariance()

    toy.load_photo_vary_fits(pkg_set1 = ['./inputs/quadfits_LRG_abacus_Y1_Ksys_SGC_xi0.csv',
                                        './inputs/quadfits_LRG_abacus_Y1_Ksys_SGC_xi2.csv',
                                        './inputs/quadfits_LRG_abacus_Y1_Ksys_SGC_xi4.csv'],
                            pkg_set2 = ['./inputs/quadfits_LRG_abacus_Y1_Ksys_DEC_xi0.csv',
                                        './inputs/quadfits_LRG_abacus_Y1_Ksys_DEC_xi2.csv',
                                        './inputs/quadfits_LRG_abacus_Y1_Ksys_DEC_xi4.csv'],
                            pkg_set3 = ['./inputs/quadfits_LRG_abacus_Y1_Ksys_MZLS_xi0.csv',
                                        './inputs/quadfits_LRG_abacus_Y1_Ksys_MZLS_xi2.csv',
                                        './inputs/quadfits_LRG_abacus_Y1_Ksys_MZLS_xi4.csv'])

    toy.test_model_base_pars(min_type = 'pseudo',
                            poi_hard_lims = ((-250,250),(0.5,4)), 
                            gauss_priors = ((1.94,0.04),(1.94,0.04),(1,0.1),(1,0.1)),
                            Psys1_gauss_prior = (0,10),
                            Psys2_gauss_prior = (0,10),
                            Psys3_gauss_prior = (0,10),
                            z_eff = 0.780, # v1.5 0.780, nbody png 0.787
                            Om_m0_g = 0.315,
                            z_fid = 0.776,
                            zhalo = 0.787, # box 0.819, y3 0.787
                            Om_m0_h = 0.3089, #
                            nwalkers = 75, #50
                            nsteps = 2000, # Should default to 20000, set to 2000 for code testing
                            plt_color = 'green',
                            fname = None, 
                            poi_toy = (fnl,b1), nuiss_toy = (1.8, 1.8, 1, 1), Psys1_toy = 0, Psys2_toy = 0, Psys3_toy = 0,
                            # data_obs = f'./inputs/Y1_LRG_correlations_v1.5_.fits',
                            plt_out = True)
    
    toy.wrap_chain_base_pars(burn_in_steps = 500, thinner = 1,
                         fname_chain = f'./outputs/toychain_fnl{fnl}_b1{b1}.txt')

# %% [markdown]
# # Initializing the chain object and creating corner plots

# %%
# Import the chain class
from codes.chain import chain

# Import the function to make corner plots
from codes.corner_plots import make_corner

# %% [markdown]
# The chain object is very simple at the moment. To load it all you need to specify is the filepath to the chain a label (to be used for plotting).

# %%
testchain = chain('./outputs/testchain.txt', label='Y1 Data')

# %% [markdown]
# If you have a chain object, plotting is very simple. All you need to do is pass the list of chains you want plotted to the make_corner function. By default it will plot fnl, b1, and the three Ksys parameters.

# %%
make_corner([testchain])

# %% [markdown]
# If you want to plot multiple chains on the same plot, simply add more to the list. By default, colors are assigned to the chains according to their order in the list, and the font sizes automatically scale so that labels are readable.

# %%
# load the toy model chains
ps1 = chain(f'./outputs/toychain_fnl-20_b11.6.txt', label='pseudo 1') # chain for pseudo 1
ps2 = chain(f'./outputs/toychain_fnl-10_b11.7.txt', label='pseudo 2') # chain for pseudo 2
ps3 = chain(f'./outputs/toychain_fnl0_b11.8.txt', label='pseudo 3') # chain for pseudo 3
ps4 = chain(f'./outputs/toychain_fnl10_b11.9.txt', label='pseudo 4') # chain for pseudo 4
ps5 = chain(f'./outputs/toychain_fnl20_b12.0.txt', label='pseudo 5') # chain for pseudo 5

# %%
make_corner([ps1, ps2, ps3, ps4, ps5])

# %% [markdown]
# Let's say you have mutliple datasets (for example, LRGs and QSOs) and want to keep consistent color schemes throughout the whole project. The you can give a chain object a color that you want it to have.

# %%
testchain.color = 'blue'
ps1.color = 'green'

# %% [markdown]
# Now if we plot these chains...

# %%
make_corner([testchain, ps1])

# %% [markdown]
# The colors are still loaded by default according to their order in the list. If pass the usecolors=True to the plotting function, it will instead use the colors we have assigned to them.

# %%
make_corner([testchain, ps1], usecolors=True)

# %% [markdown]
# Lastly, there are other optional parameters we can set. For example, we can remove the black dashed priors on Ksys by setting "ksys_prior=False". Or we can give the corner plot a title by passing a string to the "title" argument. If we want to save the figure, we have to set "savefig=True" and specify the full output filename with "outfile". By default, if "savefig" is set to true and no output directory is specified it will save to './figures/'. The output directory can be changed by setting it specifically as "figdir".

# %%
make_corner([testchain, ps1], 
            usecolors=True,
            ksys_prior=False,
            title='Example corner plot',
            savefig=True,
            outfile='example_corner.jpg')
